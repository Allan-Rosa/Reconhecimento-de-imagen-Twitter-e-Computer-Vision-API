# %%
import tweepy as tw

# %%
consumer_key = 'iPEmmao4B2yc4ittiKgtFtunD'
consumer_key_secret = 'K0EtyWEg6mpDmPrqt2rEFPCzSwJjYL65GDw0OOJJaM3wK3pMIw'
access_token = '133113722-iwppg0sScyPHHMtMKreDicZIibKJ4LtfTCsAfOyl'
access_token_secret = '2wNgoNTtgjRG88xiDUwoZB7uedW6FimXpxxAxaU5xNuLT'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_key_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
api = tw.API(auth)

# %%
tweet = api.update_status("Python e Twitter")

# %%
tweet._json
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Jan 22 22:57:54 +0000 2020',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1220118419326021634,
#  'id_str': '1220118419326021634',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'de',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://github.com/Allan-Rosa" rel="nofollow">reconhecimento-de-imagem</a>',
#  'text': 'Python e Twitter',
#  'truncated': False,
#  'user': {'can_media_tag': True,
#   'contributors_enabled': False,
#   'created_at': 'Thu Apr 15 01:53:59 +0000 2010',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Curioso. Gosto de saber de tudo um pouco! Me ofereça uma boa história que eu te devolvo duas!',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 455,
#   'follow_request_sent': False,
#   'followed_by': False,
#   'followers_count': 41,
#   'following': False,
#   'friends_count': 27,
#   'geo_enabled': False,
#   'has_extended_profile': True,
#   'id': 133113722,
#   'id_str': '133113722',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 0,
#   'location': 'São Paulo, Brasil',
#   'name': 'Allan Martins Rosa',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1129821590487818240/CotBPsHH_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1129821590487818240/CotBPsHH_normal.png',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'Allan_Martins_',
#   'statuses_count': 309,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %% [markdown]
# # Pesquisando Tweets

# %%
tweets = tw.Cursor(api.search, 
                   q="data science", 
                   since='2020-01-01', 
                   lang='pt').items(20)

# %%
for tweet in tweets:
  print(tweet.text)
  print('-- -- -- -- ' * 10)
# Out:
# [Job] Data Science Intern | Company: InstaCarro | Location: São Paulo SP  Brazil | #São #Paulo #Systems #Science… https://t.co/MJHRjluiVa
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# @anhembimorumbi Quero fazer minha inscrição no curso de especialização em Data Science
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# RT @qdoisdata: 🐋 Ontem tivemos o início da nossa QUniversity! 🐋
#
# A #QUni é a nossa iniciativa responsável por qualificar cada dia mais noss…
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# RT @qdoisdata: 🐋 Ontem tivemos o início da nossa QUniversity! 🐋
#
# A #QUni é a nossa iniciativa responsável por qualificar cada dia mais noss…
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# RT @qdoisdata: 🐋 Ontem tivemos o início da nossa QUniversity! 🐋
#
# A #QUni é a nossa iniciativa responsável por qualificar cada dia mais noss…
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# 🐋 Ontem tivemos o início da nossa QUniversity! 🐋
#
# A #QUni é a nossa iniciativa responsável por qualificar cada dia… https://t.co/G2DouORQJN
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# @Ogidnem Nenhuma dessas delícias: mestrado no exterior. Só q em linguística, não em Direito. Preciso completar algu… https://t.co/AUtJVbQz3H
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# @meninadochapeu_ Opiniões sobre os cursos pagos da Data Science Academy?
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Resolvendo um problema de data science que ninguém tá conseguindo resolver
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Seis libros para aprender acerca de Data Science https://t.co/VavbZVb4Xt
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Data science me deixa hypado só pelas infinitas possibilidades que oferece
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# RT @_Seikiti: O ser humano se acha especial a todo custo, mas adora fazer tudo como a maioria. Tão previsíveis que com data science um algo…
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# O ser humano se acha especial a todo custo, mas adora fazer tudo como a maioria. Tão previsíveis que com data scien… https://t.co/DRqKy9sjL9
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# No curso que estou fazendo tem exatamente 15 homens e apenas eu de mulher ,me sinto inteligente demais em muita das… https://t.co/QMM8l026Lh
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Hoje eu iniciei os estudos em Data Science (fui para um curso de Deep Learning que ainda tenho de terminar) e os li… https://t.co/aRESxb8C0k
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# @_JonWick Minha home do YT é: NBA; Key &amp; Peele; ASMR; Data Science e Vídeos sobre música (não de música, SOBRE).
#
# * Cálculo diferencial?????
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# 3/5 Não consegui pensar agora em um exemplo no direito mas tem um exemplo que gosto bastante e vi no link abaixo. A… https://t.co/FcOLDDpA1N
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# @lnunesjr O data science revolucionou e vai reolucionar mais ainda o mundo
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# Seis libros para aprender acerca de Data Science https://t.co/xduTxHkCed
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# @tavasconcellos Tenho uma sensação que os jornalistas estão sendo manipulados, já perceberam e não estão conseguind… https://t.co/cN5yJdXInw
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %%
tweets = tw.Cursor(api.search, 
                   q="inteligência artificial", 
                   since='2020-01-01', 
                   lang='pt').items(10)

# %%
for tweet in tweets:
  print(tweet.text)
  print(tweet.user.screen_name)
  print(tweet.user.location)
  print('-- -- -- -- ' * 10, '\n')
# Out:
# Inteligência Artificial o Robô da Loto https://t.co/1nmE4hVywJ via @YouTube
# JAderaldo
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# RT @Accenture: Existe a Inteligência Artificial. E existe a #InteligênciaAplicada. Veja como transformamos os negócios.
# Uroubouros
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# RT @Schwarza79: Criaram o Primeiro Robô Vivo do Mundo Usando Células de Sapo e Inteligência Artificial!: https://t.co/yjkH2FTXgQ https://t.…
# Praatofeito
# Salamanca
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Todas as pesquisas apontam q a Inteligência Artificial será uma das tecnologias que apresentarão grande expansão no… https://t.co/CdW4PB7Ue8
# BRpaisdigital
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# RT @_catatau: 'em 2020 todos terão um robô com inteligência artificial pra ajudar nas tarefas domésticas, haverá cidades submarinas, carros…
# dianabfreitas
# Brasília
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# RT @EscolaDeDados: INTELIGÊNCIA ARTIFICIAL E JORNALISMO
#
# O que aprendemos sobre inteligência artificial e por que jornalistas devem se impo…
# ocesarbeck
# Hell de Janeiro
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Na abertura da 2ª temporada do nosso podcast, entrevistamos Alexandre Del Rey sobre Inteligência Artificial no Bras… https://t.co/5opbqErdzA
# douglastaub
# São Paulo/SP - Brasil
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# RT @Schwarza79: Criaram o Primeiro Robô Vivo do Mundo Usando Células de Sapo e Inteligência Artificial!: https://t.co/yjkH2FTXgQ https://t.…
# JoaoM10000
# Brazil
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Criaram o Primeiro Robô Vivo do Mundo Usando Células de Sapo e Inteligência Artificial!: https://t.co/yjkH2FTXgQ https://t.co/6FwhlJtAO7
# Schwarza79
# Brazil
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# RT @_catatau: 'em 2020 todos terão um robô com inteligência artificial pra ajudar nas tarefas domésticas, haverá cidades submarinas, carros…
# eduardomsimoes_
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %%
famosos = ['cauareymond','aguiarthur','ivetesangalo','ClaudiaLeitte','neymarjr','BruMarquezine','mariruybarbosa',
'FePaesLeme','Tatawerneck','FlaviaAleReal','julianapaes','dedesecco','SabrinaSato','ahickmann','gusttavo_lima','Anitta',
'CarolCastroReal','gio_antonelli','maisa','cleooficial','gewbank','taisdeverdade','otaviano','bernardipaloma',
'IngridGuimaraes','olazaroramos','GalisteuOficial','debranascimento','FioMattheis','moalfradique','Nandacostareal']

# %%
len(famosos)
# Out:
# 31

# %%
for famoso in famosos:
  tweets = tw.Cursor(api.search, 
                   q=famoso, 
                   since='2019-01-10').items(5)
  print('Autor: ', famoso)
  print('Imagens postadas:')

  for tweet in tweets:
    if 'media' in tweet.entities:
      print(tweet.entities['media'][0]['media_url'])
      
  print('-- -- -- -- ' * 10, '\n')
# Out:
# Autor:  cauareymond
# Imagens postadas:
# http://pbs.twimg.com/media/EO6z8G5XUAI023Y.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  aguiarthur
# Imagens postadas:
# http://pbs.twimg.com/media/EO5YYEFU8AE8_K1.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  ivetesangalo
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  ClaudiaLeitte
# Imagens postadas:
# http://pbs.twimg.com/ext_tw_video_thumb/1218347218329112576/pu/img/4Gwd5kKGCDbB7XF6.jpg
# http://pbs.twimg.com/ext_tw_video_thumb/1219998935407906816/pu/img/KAENIYoA4lySbDK9.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  neymarjr
# Imagens postadas:
# http://pbs.twimg.com/tweet_video_thumb/EO6ddTRWAAAEYNb.jpg
# http://pbs.twimg.com/tweet_video_thumb/EO6ddTRWAAAEYNb.jpg
# http://pbs.twimg.com/ext_tw_video_thumb/1219933254897283072/pu/img/3VDJydYseT9w6_8W.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  BruMarquezine
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  mariruybarbosa
# Imagens postadas:
# http://pbs.twimg.com/media/EO6qJTxXkAABiDh.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  FePaesLeme
# Imagens postadas:
# http://pbs.twimg.com/media/EO6r4svXkAUU609.jpg
# http://pbs.twimg.com/ext_tw_video_thumb/1125567652880093189/pu/img/Z1wgN7guMrD6N61_.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  Tatawerneck
# Imagens postadas:
# http://pbs.twimg.com/ext_tw_video_thumb/1216104181079199744/pu/img/5IbY9lOtyX8y8b4v.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  FlaviaAleReal
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  julianapaes
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  dedesecco
# Imagens postadas:
# http://pbs.twimg.com/tweet_video_thumb/EO5KKcnWkAELwcC.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  SabrinaSato
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  ahickmann
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  gusttavo_lima
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  Anitta
# Imagens postadas:
# http://pbs.twimg.com/ext_tw_video_thumb/1219687025219186689/pu/img/3Qj6W2qgvoKa5xGp.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  CarolCastroReal
# Imagens postadas:
# http://pbs.twimg.com/media/EO0DaPPWAAImh9x.jpg
# http://pbs.twimg.com/media/EO0DaPPWAAImh9x.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  gio_antonelli
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  maisa
# Imagens postadas:
# http://pbs.twimg.com/media/EO5-Ar2WAAcHk7J.jpg
# http://pbs.twimg.com/media/EO5-Ar2WAAcHk7J.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  cleooficial
# Imagens postadas:
# http://pbs.twimg.com/media/DnGBFqcXcAUuXJG.png
# http://pbs.twimg.com/tweet_video_thumb/D1_AjxIXQAAzHPl.jpg
# http://pbs.twimg.com/ext_tw_video_thumb/1030933095812407296/pu/img/g-u3luv5rodn7byA.jpg
# http://pbs.twimg.com/ext_tw_video_thumb/1030933095812407296/pu/img/g-u3luv5rodn7byA.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  gewbank
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  taisdeverdade
# Imagens postadas:
# http://pbs.twimg.com/media/EO6bJTSW4AYtbjW.jpg
# http://pbs.twimg.com/media/EO6JO2aXUAQDpdP.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  otaviano
# Imagens postadas:
# http://pbs.twimg.com/tweet_video_thumb/EO6xWbaWsAEpQGR.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  bernardipaloma
# Imagens postadas:
# http://pbs.twimg.com/media/EOZlwDdWAAEeYyc.jpg
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  IngridGuimaraes
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  olazaroramos
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  GalisteuOficial
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  debranascimento
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  FioMattheis
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  moalfradique
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# Autor:  Nandacostareal
# Imagens postadas:
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --

# %% [markdown]
# # Streaming

# %%
class MInhaStreamListener(tw.StreamListener):
  def on_status(self, status):
    print(tweet.user.screen_name)
    print(tweet.text)
    print(tweet.user.location)
    print('-- -- -- -- ' * 10, '\n')

# %%
minhaStream = tw.Stream(auth = auth, listener=MInhaStreamListener())

# %%
minhaStream.filter(track=famosos)
# Out:
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
#
# -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-daf42f7203f3> in <module>()
# ----> 1 minhaStream.filter(track=famosos)
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /usr/local/lib/python3.6/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     442             else:
#     443                 cache_content = False
# --> 444                 data = self._fp.read(amt)
#     445                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     446                     # Close the connection when no data is returned
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/lib/python3.6/http/client.py in readinto(self, b)
#     491
#     492         if self.chunked:
# --> 493             return self._readinto_chunked(b)
#     494
#     495         if self.length is not None:
#
# /usr/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     586         try:
#     587             while True:
# --> 588                 chunk_left = self._get_chunk_left()
#     589                 if chunk_left is None:
#     590                     return total_bytes
#
# /usr/lib/python3.6/http/client.py in _get_chunk_left(self)
#     554                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     555             try:
# --> 556                 chunk_left = self._read_next_chunk_size()
#     557             except ValueError:
#     558                 raise IncompleteRead(b'')
#
# /usr/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     514     def _read_next_chunk_size(self):
#     515         # Read the next chunk size from the file
# --> 516         line = self.fp.readline(_MAXLINE + 1)
#     517         if len(line) > _MAXLINE:
#     518             raise LineTooLong("chunk size")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !pip install azure-cognitiveservices-vision-computervision
# Out:
# Collecting azure-cognitiveservices-vision-computervision
#   Downloading https://files.pythonhosted.org/packages/55/d8/f61816761877cdd9c0e1e2274914946e67b3a07dd59bda37636badcedba1/azure_cognitiveservices_vision_computervision-0.5.0-py2.py3-none-any.whl
# Collecting msrest>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/27/b0/c34b3ea9b2ed74b800520fbefb312cdb7f05c20b8bd42e5e7662a5614f98/msrest-0.6.10-py2.py3-none-any.whl (82kB)
#      |████████████████████████████████| 92kB 4.9MB/s
# Collecting azure-common~=1.1
#   Downloading https://files.pythonhosted.org/packages/3f/4b/8881f8446853dfe3d404468689edcff33c0e2bf62ac2ddf31d08d739fadc/azure_common-1.1.24-py2.py3-none-any.whl
# Requirement already satisfied: requests~=2.16 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2019.11.28)
# Collecting isodate>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.4MB/s
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.3.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests~=2.16->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (1.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision) (3.1.0)
# Installing collected packages: isodate, msrest, azure-common, azure-cognitiveservices-vision-computervision
# Successfully installed azure-cognitiveservices-vision-computervision-0.5.0 azure-common-1.1.24 isodate-0.6.0 msrest-0.6.10

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

# %%
credenciais = CognitiveServicesCredentials("1d6fd960192e4430abda34aaed41021e")

# %%
client = ComputerVisionClient("https://reconhecimento-de-imagem.cognitiveservices.azure.com", credenciais)

# %%
client.api_version
# Out:
# '2.1'

# %% [markdown]
# ![](https://pbs.twimg.com/ext_tw_video_thumb/1179834553147494400/pu/img/Hi4fFTMMAJJ8PCwM.jpg)

# %%
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes

url = "https://pbs.twimg.com/ext_tw_video_thumb/1179834553147494400/pu/img/Hi4fFTMMAJJ8PCwM.jpg"

analize_de_imagem = client.analyze_image(url, VisualFeatureTypes.tags)

# %%
for tag in analize_de_imagem.tags:
  print(tag)
# Out:
# {'additional_properties': {}, 'name': 'person', 'confidence': 0.9971672296524048, 'hint': None}
# {'additional_properties': {}, 'name': 'human face', 'confidence': 0.9817132949829102, 'hint': None}
# {'additional_properties': {}, 'name': 'clothing', 'confidence': 0.968743085861206, 'hint': None}
# {'additional_properties': {}, 'name': 'smile', 'confidence': 0.9355480074882507, 'hint': None}
# {'additional_properties': {}, 'name': 'curtain', 'confidence': 0.8865094184875488, 'hint': None}
# {'additional_properties': {}, 'name': 'standing', 'confidence': 0.8721498250961304, 'hint': None}
# {'additional_properties': {}, 'name': 'woman', 'confidence': 0.8382598161697388, 'hint': None}
# {'additional_properties': {}, 'name': 'suit', 'confidence': 0.7841097116470337, 'hint': None}
# {'additional_properties': {}, 'name': 'dark', 'confidence': 0.4113442301750183, 'hint': None}
# {'additional_properties': {}, 'name': 'posing', 'confidence': 0.36758750677108765, 'hint': None}
# {'additional_properties': {}, 'name': 'dressed', 'confidence': 0.3588613271713257, 'hint': None}

# %%
analise_celebridades = client.analyze_image_by_domain("celebrities", url, "en")

# %%
for celebridade in analise_celebridades.result["celebrities"]:
  print(celebridade['name'])
  print(celebridade['confidence'])
# Out:
# Giovanna Ewbank
# 0.9772043824195862

# %%
analise_celebridades.result["celebrities"]
# Out:
# [{'confidence': 0.9772043824195862,
#   'faceRectangle': {'height': 54, 'left': 368, 'top': 67, 'width': 54},
#   'name': 'Giovanna Ewbank'}]

# %%
descricao = client.describe_image(url, 3, "en")

# %%
for capition in descricao.captions:
  print(capition.text)
  print(capition.confidence)
# Out:
# Giovanna Ewbank standing in front of a curtain
# 0.8947538055232972
# Giovanna Ewbank wearing a suit and tie
# 0.8937538055232972
# Giovanna Ewbank wearing a black dress standing in front of a curtain
# 0.8080114537903335

# %% [markdown]
# # Streaming + Vision API

# %%
api.get_user('jcalvesol').id_str
# Out:
# '917548352446791685'

# %%
famosos_id = []

for famoso in famosos:
  famoso_id = api.get_user(famoso).id_str
  famosos_id.append(famoso_id)

# %%
import json

# %%
class MInhaStreamListener(tw.StreamListener):
  def on_status(self, status):
    print(tweet.user.screen_name)
    print(tweet.text)
    
    if 'media' in status.entities:
      url = status.entities['media'][0]['media_url']
      print("URL: ", url)

      analise_celebridades = client.analyze_image_by_domain("celebrities", url, "en")
      lista_celebridades = [ celebridade['name'] for celebridade in analise_celebridades.result["celebrities"] ]
      print(lista_celebridades)

      descricao = client.describe_image(url, 1, "en")
      texto_descricao = descricao.captions[0].text
      print("Descricao: ", texto_descricao)

      analize_de_imagem = client.analyze_image(url, VisualFeatureTypes.tags)
      lista_tags = [ tag.name for tag in analize_de_imagem.tags ]
      print("tag: ", lista_tags)

      resultados = {
          'usuario': status.user.screen_name,
          'texto': status.text,
          'url': url ,
          'celebridades': lista_celebridades ,
          'descricao': texto_descricao,
          'tags': lista_tags
      }

      with open('tweets.txt', 'a') as arquivo:
        arquivo.write(json.dumps(resultados))
        arquivo.write('\n')

    print('-- -- -- -- ' * 10, '\n')

# %%
minhaStream = None

# %%
minhaStream = tw.Stream(auth = auth, listener=MInhaStreamListener())

# %%
minhaStream.filter(follow=famosos_id)
# Out:
# helmermassau
# @tgmartins @Nandacostareal ♥️♥️
# URL:  http://pbs.twimg.com/ext_tw_video_thumb/1218362638926860289/pu/img/8skioqT0gIG07l4-.jpg
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-c8d34de9e731> in <module>()
# ----> 1 minhaStream.filter(follow=famosos_id)
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _run(self)
#     295             # call a handler first so that the exception can be logged.
#     296             self.listener.on_exception(exc_info[1])
# --> 297             six.reraise(*exc_info)
#     298
#     299     def _data(self, data):
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _read_loop(self, resp)
#     325             next_status_obj = buf.read_len(length)
#     326             if self.running and next_status_obj:
# --> 327                 self._data(next_status_obj)
#     328
#     329             # # Note: keep-alive newlines might be inserted before each length value.
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _data(self, data)
#     298
#     299     def _data(self, data):
# --> 300         if self.listener.on_data(data) is False:
#     301             self.running = False
#     302
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in on_data(self, raw_data)
#      53         if 'in_reply_to_status_id' in data:
#      54             status = Status.parse(self.api, data)
# ---> 55             if self.on_status(status) is False:
#      56                 return False
#      57         elif 'delete' in data:
#
# <ipython-input-33-713213481e0c> in on_status(self, status)
#      13
#      14       descricao = client.describe_image(url, 1, "en")
# ---> 15       texto_descricao = descricao.captions[0].text
#      16       print("Descricao: ", texto_descricao)
#      17
#
# IndexError: list index out of range

# %% [markdown]
# #**Avaliando Resultados**

# %%
 lista_arquivo = []
 with open("tweets.txt", 'r') as arquivo:
   for linha in arquivo:
     lista_arquivo.append(json.loads(linha))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-fc9baf5b5835> in <module>()
#       1 lista_arquivo = []
# ----> 2 with open("tweets.txt", 'r') as arquivo:
#       3   for linha in arquivo:
#       4     lista_arquivo.append(json.loads(linha))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tweets.txt'

# %%
lista_arquivo[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-46ac8938a400> in <module>()
# ----> 1 lista_arquivo[0]
#
# IndexError: list index out of range

# %%
import pandas as pd

# %%
imagens = pd.DataFrame(lista_arquivo)

# %%
imagens
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pesquisa = 'outdoor'

achados = [(pesquisa in lista ) for lista in imagens.tags]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-466b1480c3ac> in <module>()
#       1 pesquisa = 'outdoor'
#       2
# ----> 3 achados = [(pesquisa in lista ) for lista in imagens.tags]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'tags'

# %%
imagens[achados].descricao.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-b3a8ddefa9d1> in <module>()
# ----> 1 imagens[achados].descricao.iloc[0]
#
# NameError: name 'achados' is not defined

# %%
imagens[achados].tags.iloc[0]

# %%
imagens[achados].url.iloc[0]
